# %%
# %matplotlib notebook
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

import numpy as np
import scipy
from astropy.io import fits

# %%
random_bias_HDU = fits.open('./taste_data/bias/AF124534.fits')

# %%
random_bias_HDU[0].header['JD']
JD = random_bias_HDU[0].header['JD']
print(JD)
# Out:
# 2455892.633151

# %%
plt.figure()
random_bias_data = random_bias_HDU[0].data
plt.imshow(random_bias_data[50:71, 100:121], clim=(440, 460))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
master_bias_HDU = fits.open('./taste_data/bias/mb.fits')
master_bias_data = master_bias_HDU[0].data
plt.imshow(master_bias_data[50:71, 100:121], clim=(440, 460))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
axs[0].imshow(random_bias_data[50:71, 100:121], clim=(440, 460))
axs[1].imshow(master_bias_data[50:71, 100:121], clim=(440, 460))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
hist_range= (440, 460)
hist_bins= hist_range[1]- hist_range[0]

_ = plt.hist(random_bias_data.flatten(), bins=hist_bins, range=hist_range, alpha=0.75, label='single bias')
_ = plt.hist(master_bias_data.flatten(), bins=hist_bins, range=hist_range, alpha=0.75, label='master bias')
plt.xlabel('Bias counts')
plt.ylabel('#')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('Standard deviation of random bias : {0:.2f}'.format(np.std(random_bias_data[50:71, 100:121])))
print('Standard deviation of master bias : {0:.2f}'.format(np.std(master_bias_data[50:71, 100:121])))
# Out:
# Standard deviation of random bias : 2.64
# Standard deviation of master bias : 0.62

# %%
2.64/np.sqrt(30)
# Out:
# 0.4819958506045462
